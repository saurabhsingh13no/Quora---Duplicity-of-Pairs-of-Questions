# %%
import json
a={"documents": [
    {
      "language": "en",
      "id": "string",
      "text": "Find the remainder when [math]23^{24}[/math] is divided by 24,23?"
    }
  ]
}


b = json.dumps(a)

import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    #'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': 'USE-YOUR-OWN-KEY', # Sorry, I exhausted my credit
}

params = urllib.parse.urlencode({})

try:
    conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
    conn.request("POST", "/text/analytics/v2.0/sentiment?%s" % params,b, headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno ] {}".format(e))
# Out:
# b'{"documents":[{"score":0.5,"id":"string"}],"errors":[]}'

# %%
application_json
# Out:
# {'documents': [{'id': 'string',
#    'language': 'en',
#    'text': 'What is the step by step guide to invest in share market in india'}]}

# %%
application_json.items()
# Out:
# dict_items([('documents', [{'id': 'string', 'language': 'en', 'text': 'What is the step by step guide to invest in share market in india'}])])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import http.client, urllib.request, urllib.parse, urllib.error, base64
quora_questions=pd.read_csv("quora_dataset_csv.csv")

# %%
quora_questions.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#    question1_senti                                          question2  \
# 0              NaN  What is the step by step guide to invest in sh...
# 1              NaN  What would happen if the Indian government sto...
# 2              NaN  How can Internet speed be increased by hacking...
# 3             0.14  Find the remainder when [math]23^{24}[/math] i...
# 4              NaN            Which fish would survive in salt water?
#
#    question2_senti  is_duplicate  Corelation_API
# 0              NaN             0          0.9732
# ...

# %%
count=1999
question_list=[]
question_senti=[]
while count<3000:
    a={"documents": [
    {
      "language": "en",
      "id": "string",
      "text": quora_questions['question2'][count],
    }
      ]
    }
    b = json.dumps(a)
    headers = {
        # Request headers
        #'Content-Type': 'application/json',
        'Ocp-Apim-Subscription-Key': 'USE YOUR OWN KEY',   # Sorry i exhauseted my own key
    }

    params = urllib.parse.urlencode({})

    try:
        conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
        conn.request("POST", "/text/analytics/v2.0/sentiment?%s" % params,b, headers)
        response = conn.getresponse()
        data = response.read()
        print(quora_questions['question2'][count], data)
        question_list.append(quora_questions['question2'][count])
        t=data.decode('utf-8')
        pattern=r'"score":([0-9.]+)'
        k=re.findall(pattern,t)
        question_senti.append(float(k[0]))
        conn.close()
        count+=1
    except Exception as e:
        print("[Errno ] {}".format(e))
# Out:
# Which is better: an arranged marriage or a love marriage? b'{"documents":[{"score":0.5,"id":"string"}],"errors":[]}'
# How do I break security code in Nokia C1? b'{"documents":[{"score":0.764436717890366,"id":"string"}],"errors":[]}'
# What is the best site to to learn data structures and algorithms from video tutorials? b'{"documents":[{"score":0.884675242169052,"id":"string"}],"errors":[]}'
# How do I torrent on my college network without being detected or getting caught? b'{"documents":[{"score":0.5,"id":"string"}],"errors":[]}'
# What advice will you give to an IIT graduate in Mechanical/Civil Engineering, who strongly wants to pursue a research career in computer science/mathematics, and has completed the basic courses of CS in coursera? b'{"documents":[{"score":0.862117456499742,"id":"string"}],"errors":[]}'
# What universities does Federal Signal recruit new grads from? What majors are they looking for? b'{"documents":[{"score":0.5,"id":"string"}],"errors":[]}'
# ...

# %%
# print (question_list)
# print (question_senti)
df=pd.DataFrame()
df['quesiton']=question_list
df.to_csv("question_list.csv")
df=pd.DataFrame()
df['senti']=question_senti
df.to_csv("question_senti.csv")

# %%
df1=pd.DataFrame()
df1['questionsenti']=question_senti
df1.to_csv("list_senti.csv")
